# %% [markdown]
# # train a model

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# ## Import Data

# %%
#read train 
deaths = pd.read_csv('deaths.csv')
cases = pd.read_csv('cases.csv')
deaths.head()
# Out:
#   Province/State Country/Region    Territory  Population      Lat     Long  \
# 0            NaN    Afghanistan  Afghanistan  26023100.0  33.0000  65.0000
# 1            NaN        Albania      Albania   2895947.0  41.1533  20.1683
# 2            NaN        Algeria      Algeria  38700000.0  28.0339   1.6596
# 3            NaN        Andorra      Andorra         NaN  42.5063   1.5218
# 4            NaN         Angola       Angola  24383301.0 -11.2027  17.8739
#
#    1/22/20  1/23/20  1/24/20  1/25/20  ...  3/30/20  3/31/20  4/1/20  4/2/20  \
# 0        0        0        0        0  ...        4        4       4       6
# 1        0        0        0        0  ...       11       15      15      16
# 2        0        0        0        0  ...       35       44      58      86
# 3        0        0        0        0  ...        8       12      14      15
# 4        0        0        0        0  ...        2        2       2       2
#
#    4/3/20  4/4/20  4/5/20  4/6/20  4/7/20  4/8/20
# ...

# %%
deaths.drop(['Province/State'], axis=True)
# Out:
#                        Country/Region  \
# 0                         Afghanistan
# 1                             Albania
# 2                             Algeria
# 3                             Andorra
# 4                              Angola
# 5                 Antigua and Barbuda
# 6                           Argentina
# 7                             Armenia
# 8                           Australia
# 9                           Australia
# 10                          Australia
# 11                          Australia
# 12                          Australia
# 13                          Australia
# 14                          Australia
# 15                          Australia
# 16                            Austria
# 17                         Azerbaijan
# 18                            Bahamas
# 19                            Bahrain
# 20                         Bangladesh
# 21                           Barbados
# 22                            Belarus
# ...

# %%
## Add many variables
cases.shape
# Out:
# (274, 83)

# %%
deaths.shape
# Out:
# (274, 84)

# %% [raw]
# #transpose data frame
# deaths.T

# %% [markdown]
# ## Add variables

# %% [markdown]
# ### Temperature

# %%
import requests
import lxml.html as lh

# %%
def web_scraping_data(link):
    #Create a handle, page, to handle the contents of the website
    page = requests.get(link)
    doc = lh.fromstring(page.content)
    tr_elements = doc.xpath('//tr')

    tr_elements = doc.xpath('//tr')
    col=[]
    i=0
    for t in tr_elements[0]:
        i+=1
        name=t.text_content()
        #print ('%d:"%s"'%(i,name))
        col.append((name,[]))

    for j in range(1,len(tr_elements)):
        T=tr_elements[j]
        i=0

        for t in T.iterchildren():
            data=t.text_content() 
            if i>0:
                try:
                    data=int(data)
                except:
                    pass

            col[i][1].append(data)
            i+=1

    Dict={title:column for (title,column) in col}
    df=pd.DataFrame(Dict)
    
    return df

# %%
code_country = web_scraping_data("https://www.iban.com/country-codes")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/urllib/request.py in _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2559                 try:
# -> 2560                     hostIP = socket.gethostbyname(hostonly)
#    2561                     hostIP = ip2num(hostIP)
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-010392c1370a> in <module>
# ----> 1 code_country = web_scraping_data("https://www.iban.com/country-codes")
#       2 code_country.head(3)
#
# <ipython-input-29-acebb83195d3> in web_scraping_data(link)
#       1 def web_scraping_data(link):
#       2     #Create a handle, page, to handle the contents of the website
# ...

# %%
code_country.head(10)
# Out:
#                Country Alpha-2 code Alpha-3 code  Numeric
# 0          Afghanistan           AF          AFG        4
# 1        Åland Islands           AX          ALA      248
# 2              Albania           AL          ALB        8
# 3              Algeria           DZ          DZA       12
# 4       American Samoa           AS          ASM       16
# 5              Andorra           AD          AND       20
# 6               Angola           AO          AGO       24
# 7             Anguilla           AI          AIA      660
# 8           Antarctica           AQ          ATA       10
# 9  Antigua and Barbuda           AG          ATG       28

# %%
code_country.shape
# Out:
# (249, 4)

# %% [markdown]
# Source
# - https://datacatalog.worldbank.org/dataset/climate-change-knowledge-portal-historical-data

# %%
temp = pd.read_csv('temp.csv')
temp.head(10)
# Out:
#   ISO_3DIGIT  Jan_Temp  Feb_temp  Mar_temp  Apr_Temp  May_temp  Jun_Temp  \
# 0        AFG      0.07      2.11      7.60     13.37     18.22     23.20
# 1        AGO     22.58     22.68     22.78     22.35     20.74     18.37
# 2        ALB      2.02      3.22      6.04      9.92     14.44     17.93
# 3        ARE     18.43     19.43     22.61     26.58     30.62     32.46
# 4        ARG     20.80     19.90     17.51     14.05     10.65      7.66
# 5        ARM     -8.66     -6.65     -0.57      6.62     11.43     15.58
# 6        AUS     27.78     27.23     25.37     21.87     17.86     14.83
# 7        AUT     -3.52     -1.99      1.42      5.51     10.12     13.29
# 8        AZE     -0.20      0.80      4.97     11.64     16.80     21.73
# 9        BDI     20.24     20.39     20.43     20.37     20.05     19.37
#
#    July_Temp  Aug_Temp  Sept_temp  Oct_temp  Nov_Temp  Dec_temp  Annual_temp
# 0      25.26     23.77      19.03     12.99      7.00      2.43        12.92
# ...

# %%
temp.shape
# Out:
# (178, 14)

# %%
temperature = pd.merge(left=temp, right=code_country, left_on='ISO_3DIGIT', right_on='Alpha-3 code')

# %%
temperature = temperature.drop(['Numeric','Alpha-2 code','Alpha-3 code'], axis=True)

# %%
temperature.shape
# Out:
# (177, 15)

# %%
temperature.head(4)
# Out:
#   ISO_3DIGIT  Jan_Temp  Feb_temp  Mar_temp  Apr_Temp  May_temp  Jun_Temp  \
# 0        AFG      0.07      2.11      7.60     13.37     18.22     23.20
# 1        AGO     22.58     22.68     22.78     22.35     20.74     18.37
# 2        ALB      2.02      3.22      6.04      9.92     14.44     17.93
# 3        ARE     18.43     19.43     22.61     26.58     30.62     32.46
#
#    July_Temp  Aug_Temp  Sept_temp  Oct_temp  Nov_Temp  Dec_temp  Annual_temp  \
# 0      25.26     23.77      19.03     12.99      7.00      2.43        12.92
# 1      17.95     19.90      22.19     23.18     22.79     22.61        21.51
# 2      20.54     20.48      17.16     12.27      7.58      3.65        11.27
# 3      33.80     33.55      31.74     28.34     24.06     20.28        26.83
#
#                       Country
# 0                 Afghanistan
# 1                      Angola
# 2                     Albania
# 3  United Arab Emirates (the)

# %%
len(deaths.Territory.unique())
# Out:
# 209

# %%
deaths.shape
# Out:
# (274, 84)

# %%
merge = pd.merge(left=deaths, right=temperature, left_on='Territory', right_on='Country')

# %%
merge.shape
# Out:
# (229, 99)

# %%
274-229
# Out:
# 45

# %% [markdown]
# I am loosing 45 countries.

# %%
sum(deaths.Territory == 'France')
# Out:
# 3

# %%
deaths[deaths.Territory == 'France']
# Out:
#                 Province/State Country/Region Territory  Population      Lat  \
# 114                 Martinique         France    France  66078000.0  14.6415
# 115                        NaN         France    France  66078000.0  46.2276
# 253  Saint Pierre and Miquelon         France    France  66078000.0  46.8852
#
#         Long  1/22/20  1/23/20  1/24/20  1/25/20  ...  3/30/20  3/31/20  \
# 114 -61.0242        0        0        0        0  ...        1        3
# 115   2.2137        0        0        0        0  ...     3024     3523
# 253 -56.3159        0        0        0        0  ...        0        0
#
#      4/1/20  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20  4/7/20  4/8/20
# 114       3       3       3       3       4       4       4       6
# 115    4032    5387    6507    7560    8078    8911   10328   10869
# 253       0       0       0       0       0       0       0       0
#
# [3 rows x 84 columns]
