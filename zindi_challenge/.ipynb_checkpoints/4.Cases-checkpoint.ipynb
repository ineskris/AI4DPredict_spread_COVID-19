# %% [markdown]
# ## Final File

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
#Read train 
deaths = pd.read_csv('data/deaths.csv')
cases = pd.read_csv('data/cases.csv')
deaths.drop(['Province/State'], axis=True)
deaths.shape
# Out:
# (274, 84)

# %%
df = pd.read_csv('Global_variable_per_country+Intervention+Africa.csv')
df.shape
# Out:
# (274, 138)

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
# no missing values
missing_value_df[missing_value_df.percent_missing!=0]
# Out:
# Empty DataFrame
# Columns: [column_name, percent_missing]
# Index: []

# %% [markdown]
# We will add the number of cases.

# %%
cases.drop(['Lat','Long','Province/State','Territory'], axis=1, inplace=True)

# %%
cases.shape
# Out:
# (274, 79)

# %%
df = df.merge(cases, how='left', left_on='Country/Region', right_on='Country/Region')
# df.drop(['Country/Region_x'], axis=1, inplace=True)

# %%
df.to_csv('Final-DATA.csv',index=False)

# %%
df.shape
# Out:
# (1842, 216)

# %%
missing_value_df
# Out:
#                    column_name  percent_missing
# Province/State  Province/State              0.0
# Country/Region  Country/Region              0.0
# Territory            Territory              0.0
# Population          Population              0.0
# Lat                        Lat              0.0
# Long                      Long              0.0
# 1/22/20_x            1/22/20_x              0.0
# 1/23/20_x            1/23/20_x              0.0
# 1/24/20_x            1/24/20_x              0.0
# 1/25/20_x            1/25/20_x              0.0
# 1/26/20_x            1/26/20_x              0.0
# 1/27/20_x            1/27/20_x              0.0
# 1/28/20_x            1/28/20_x              0.0
# 1/29/20_x            1/29/20_x              0.0
# 1/30/20_x            1/30/20_x              0.0
# 1/31/20_x            1/31/20_x              0.0
# 2/1/20_x              2/1/20_x              0.0
# 2/2/20_x              2/2/20_x              0.0
# 2/3/20_x              2/3/20_x              0.0
# 2/4/20_x              2/4/20_x              0.0
# 2/5/20_x              2/5/20_x              0.0
# 2/6/20_x              2/6/20_x              0.0
# 2/7/20_x              2/7/20_x              0.0
# 2/8/20_x              2/8/20_x              0.0
# 2/9/20_x              2/9/20_x              0.0
# 2/10/20_x            2/10/20_x              0.0
# 2/11/20_x            2/11/20_x              0.0
# 2/12/20_x            2/12/20_x              0.0
# 2/13/20_x            2/13/20_x              0.0
# 2/14/20_x            2/14/20_x              0.0
# ...                        ...              ...
# 3/10/20_y            3/10/20_y              0.0
# 3/11/20_y            3/11/20_y              0.0
# 3/12/20_y            3/12/20_y              0.0
# 3/13/20_y            3/13/20_y              0.0
# 3/14/20_y            3/14/20_y              0.0
# 3/15/20_y            3/15/20_y              0.0
# 3/16/20_y            3/16/20_y              0.0
# 3/17/20_y            3/17/20_y              0.0
# 3/18/20_y            3/18/20_y              0.0
# 3/19/20_y            3/19/20_y              0.0
# 3/20/20_y            3/20/20_y              0.0
# 3/21/20_y            3/21/20_y              0.0
# 3/22/20_y            3/22/20_y              0.0
# 3/23/20_y            3/23/20_y              0.0
# 3/24/20_y            3/24/20_y              0.0
# 3/25/20_y            3/25/20_y              0.0
# 3/26/20_y            3/26/20_y              0.0
# 3/27/20_y            3/27/20_y              0.0
# 3/28/20_y            3/28/20_y              0.0
# 3/29/20_y            3/29/20_y              0.0
# 3/30/20_y            3/30/20_y              0.0
# 3/31/20_y            3/31/20_y              0.0
# 4/1/20_y              4/1/20_y              0.0
# 4/2/20_y              4/2/20_y              0.0
# 4/3/20_y              4/3/20_y              0.0
# 4/4/20_y              4/4/20_y              0.0
# 4/5/20_y              4/5/20_y              0.0
# 4/6/20_y              4/6/20_y              0.0
# 4/7/20_y              4/7/20_y              0.0
# 4/8/20_y              4/8/20_y              0.0
#
# [216 rows x 2 columns]

# %%
cols = df.columns.tolist()

# %%
cols
# Out:
# ['Province/State',
#  'Country/Region',
#  'Territory',
#  'Population',
#  'Lat',
#  'Long',
#  '1/22/20_x',
#  '1/23/20_x',
#  '1/24/20_x',
#  '1/25/20_x',
#  '1/26/20_x',
#  '1/27/20_x',
#  '1/28/20_x',
#  '1/29/20_x',
#  '1/30/20_x',
#  '1/31/20_x',
#  '2/1/20_x',
#  '2/2/20_x',
#  '2/3/20_x',
#  '2/4/20_x',
#  '2/5/20_x',
#  '2/6/20_x',
#  '2/7/20_x',
#  '2/8/20_x',
#  '2/9/20_x',
#  '2/10/20_x',
#  '2/11/20_x',
#  '2/12/20_x',
#  '2/13/20_x',
#  '2/14/20_x',
#  '2/15/20_x',
#  '2/16/20_x',
#  '2/17/20_x',
#  '2/18/20_x',
#  '2/19/20_x',
#  '2/20/20_x',
#  '2/21/20_x',
#  '2/22/20_x',
#  '2/23/20_x',
#  '2/24/20_x',
#  '2/25/20_x',
#  '2/26/20_x',
#  '2/27/20_x',
#  '2/28/20_x',
#  '2/29/20_x',
#  '3/1/20_x',
#  '3/2/20_x',
#  '3/3/20_x',
#  '3/4/20_x',
#  '3/5/20_x',
#  '3/6/20_x',
#  '3/7/20_x',
#  '3/8/20_x',
#  '3/9/20_x',
#  '3/10/20_x',
#  '3/11/20_x',
#  '3/12/20_x',
#  '3/13/20_x',
#  '3/14/20_x',
#  '3/15/20_x',
#  '3/16/20_x',
#  '3/17/20_x',
#  '3/18/20_x',
#  '3/19/20_x',
#  '3/20/20_x',
#  '3/21/20_x',
#  '3/22/20_x',
#  '3/23/20_x',
#  '3/24/20_x',
#  '3/25/20_x',
#  '3/26/20_x',
#  '3/27/20_x',
#  '3/28/20_x',
#  '3/29/20_x',
#  '3/30/20_x',
#  '3/31/20_x',
#  '4/1/20_x',
#  '4/2/20_x',
#  '4/3/20_x',
#  '4/4/20_x',
#  '4/5/20_x',
#  '4/6/20_x',
#  '4/7/20_x',
#  '4/8/20_x',
#  'Alpha-3 code',
#  'Jan_Temp',
#  'Feb_temp',
#  'Mar_temp',
#  'Apr_Temp',
#  'May_temp',
#  'Jun_Temp',
#  'July_Temp',
#  'Aug_Temp',
#  'Sept_temp',
#  'Oct_temp',
#  'Nov_Temp',
#  'Dec_temp',
#  'Annual_temp',
#  'Mers-confirmed',
#  'death_nb_sars',
#  '%+65',
#  '15-64pop',
#  'density',
#  'sex',
#  'IncomeGroup',
#  'tourism',
#  'World Rank',
#  '2019 Score',
#  'Government Integrity',
#  "Gov't Spending",
#  'Fiscal Health',
#  'Investment Freedom ',
#  'Tariff Rate (%)',
#  'Income Tax Rate (%)',
#  'Corporate Tax Rate (%)',
#  "Gov't Expenditure % of GDP ",
#  'GDP (Billions, PPP)',
#  'GDP Growth Rate (%)',
#  '5 Year GDP Growth Rate (%)',
#  'GDP per Capita (PPP)',
#  'Unemployment (%)',
#  'Inflation (%)',
#  'Public Debt (% of GDP)',
#  'o-im',
#  'continent',
#  'pop_obsesity',
#  'Male_obesity',
#  'Female_obesity',
#  'nb_beds',
#  'Tests',
#  'Positive',
#  'Tests/ million',
#  'Positive/ thousands',
#  'lockdown_date',
#  'Type_lockdown',
#  'nb_trial',
#  'deaths_ebola',
#  'cases_ebola',
#  '1/22/20_y',
#  '1/23/20_y',
#  '1/24/20_y',
#  '1/25/20_y',
#  '1/26/20_y',
#  '1/27/20_y',
#  '1/28/20_y',
#  '1/29/20_y',
#  '1/30/20_y',
#  '1/31/20_y',
#  '2/1/20_y',
#  '2/2/20_y',
#  '2/3/20_y',
#  '2/4/20_y',
#  '2/5/20_y',
#  '2/6/20_y',
#  '2/7/20_y',
#  '2/8/20_y',
#  '2/9/20_y',
#  '2/10/20_y',
#  '2/11/20_y',
#  '2/12/20_y',
#  '2/13/20_y',
#  '2/14/20_y',
#  '2/15/20_y',
#  '2/16/20_y',
#  '2/17/20_y',
#  '2/18/20_y',
#  '2/19/20_y',
#  '2/20/20_y',
#  '2/21/20_y',
#  '2/22/20_y',
#  '2/23/20_y',
#  '2/24/20_y',
#  '2/25/20_y',
#  '2/26/20_y',
#  '2/27/20_y',
#  '2/28/20_y',
#  '2/29/20_y',
#  '3/1/20_y',
#  '3/2/20_y',
#  '3/3/20_y',
#  '3/4/20_y',
#  '3/5/20_y',
#  '3/6/20_y',
#  '3/7/20_y',
#  '3/8/20_y',
#  '3/9/20_y',
#  '3/10/20_y',
#  '3/11/20_y',
#  '3/12/20_y',
#  '3/13/20_y',
#  '3/14/20_y',
#  '3/15/20_y',
#  '3/16/20_y',
#  '3/17/20_y',
#  '3/18/20_y',
#  '3/19/20_y',
#  '3/20/20_y',
#  '3/21/20_y',
#  '3/22/20_y',
#  '3/23/20_y',
#  '3/24/20_y',
#  '3/25/20_y',
#  '3/26/20_y',
#  '3/27/20_y',
#  '3/28/20_y',
#  '3/29/20_y',
#  '3/30/20_y',
#  '3/31/20_y',
#  '4/1/20_y',
#  '4/2/20_y',
#  '4/3/20_y',
#  '4/4/20_y',
#  '4/5/20_y',
#  '4/6/20_y',
#  '4/7/20_y',
#  '4/8/20_y']
